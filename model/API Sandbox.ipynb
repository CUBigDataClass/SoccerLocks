# %%
import requests
from datetime import datetime, timedelta

# %%
response_leagues = requests.get("https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/leagues",
        headers = {'X-RapidAPI-Key': "1d927d8256msh5ab8f97a32f7620p183164jsnbb2b67539dd2"})

# %%
league_list = []
for league in response_leagues.json()["data"]["leagues"]:
    league_list.append(league["league_slug"])

# %%
response.headers
# Out:
# {'Access-Control-Allow-Origin': '*', 'Cache-Control': 'no-cache', 'CF-RAY': '4b6ffc8c7981cf6e-IAD', 'Content-Encoding': 'gzip', 'Content-Type': 'application/json', 'Date': 'Wed, 13 Mar 2019 18:14:15 GMT', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'RapidAPI-1.0.6', 'Set-Cookie': '__cfduid=d0cfdc3ac4dcf8b6d6edced3be4a003d51552500855; expires=Thu, 12-Mar-20 18:14:15 GMT; path=/; domain=.sportsopendata.net; HttpOnly', 'X-Powered-By': 'PHP/5.6.31', 'X-RateLimit-requests-Limit': '100', 'X-RateLimit-requests-Remaining': '97', 'Content-Length': '823', 'Connection': 'keep-alive'}

# %%
endpoint = "https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/leagues/premier-league/seasons"
key = "1d927d8256msh5ab8f97a32f7620p183164jsnbb2b67539dd2"
headers = {"X-RapidAPI-Key" : key}
if(int(remaining_requests) > 1):
    response = requests.get(endpoint, headers = headers)
remaining_requests = response.headers["X-RateLimit-requests-Remaining"]
print(remaining_requests)
# Out:
# 98

# %%
response.json()["data"]["seasons"]
# Out:
# [{'identifier': 's8mqhkoesv94jidyvcw3corhyipppmsc',
#   'league_identifier': 'u8p4cqhg0ksvklxrjwxesyumnjjlfayw',
#   'season_slug': '18-19',
#   'name': '2018-2019',
#   'season_start': '2018-08-01T00:00:00+0200',
#   'season_end': '2019-05-31T00:00:00+0200'},
#  {'identifier': 'j7em1aav5nscuwimpbtrdwvytk89zltm',
#   'league_identifier': 'u8p4cqhg0ksvklxrjwxesyumnjjlfayw',
#   'season_slug': '17-18',
#   'name': '2017-2018',
#   'season_start': '2017-08-04T00:00:00+0200',
#   'season_end': '2018-05-19T00:00:00+0200'}]

# %%
for league in active_leagues:
    endpoint = "https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/leagues/" + league + " /seasons"
    key = "1d927d8256msh5ab8f97a32f7620p183164jsnbb2b67539dd2"
    headers = {"X-RapidAPI-Key" : key}
    if(int(remaining_requests) > 1):
        response = requests.get(endpoint, headers = headers)
    remaining_requests = response.headers["X-RateLimit-requests-Remaining"]

    for season in response.json()["data"]["seasons"]:
        if season['season_slug'] == '18-19':
            start_date = datetime.strptime(season['season_start'][:10],'%Y-%m-%d').date()
            end_date = datetime.strptime(season['season_end'][:10],'%Y-%m-%d').date()
            print("League: {0}, Season: {1}, Start Date: {2}, End Date: {3} ".format(league, season["season_slug"], start_date, end_date))
            if(start_date < datetime.today().date() and datetime.today().date() < end_date):
                print("Season {0} in progress for league {1}".format(season["season_slug"],league))
# Out:
# League: bundesliga, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league bundesliga
# League: eredivisie, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league eredivisie
# League: liga, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league liga
# League: ligue1, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league ligue1
# League: premier-league, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league premier-league
# League: serie-a, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league serie-a
# League: serie-b, Season: 18-19, Start Date: 2018-08-01, End Date: 2019-05-31
# Season 18-19 in progress for league serie-b

# %%
active_leagues = ["bundesliga","eredivisie","liga","ligue1","premier-league","serie-a","serie-b"]

# %%
leauge_slug = 'serie-a'
endpoint_base = "https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/"
endpoint = endpoint_base + "leagues/{league_slug}/seasons/{season_slug}/rounds".format(
    league_slug = league_slug,season_slug = "18-19")
key = "1d927d8256msh5ab8f97a32f7620p183164jsnbb2b67539dd2"
headers = {"X-RapidAPI-Key" : key}
if(int(remaining_requests) > 1):
    response = requests.get(endpoint, headers = headers)
remaining_requests = response.headers["X-RateLimit-requests-Remaining"]

# %%
current_rounds = []
current_date = (datetime.today() - timedelta(0)).date()
#all rounds for season for each league should be stored somewhere, then loaded every day to check for current rounds
for round in response.json()["data"]["rounds"]:
    start_date = datetime.strptime(round['start_date'][:10],'%Y-%m-%d').date()
    end_date = datetime.strptime(round['end_date'][:10],'%Y-%m-%d').date()
    if start_date <= current_date and current_date  <= end_date:
        round_slug = round["round_slug"]
        current_rounds.append(round_slug)

# %%
for round_slug in current_rounds:
    league_slug = 'serie-a'
    endpoint_base = "https://sportsop-soccer-sports-open-data-v1.p.rapidapi.com/v1/"
    endpoint = endpoint_base + "leagues/{league_slug}/seasons/{season_slug}/rounds/{round_slug}/matches".format(
        league_slug = league_slug,season_slug = "18-19",round_slug = round_slug)
    key = "1d927d8256msh5ab8f97a32f7620p183164jsnbb2b67539dd2"
    headers = {"X-RapidAPI-Key" : key}
    if(int(remaining_requests) > 1):
        response = requests.get(endpoint, headers = headers)
    remaining_requests = response.headers["X-RateLimit-requests-Remaining"]
    for match in response.json()["data"]["matches"]:
        if datetime.strptime(match['date_match'][:10],'%Y-%m-%d').date() == current_date:
            print(match["home"]["team"], match["away"]["team"], match['date_match'])
# Out:
# Empoli Napoli 2019-04-03T19:00:00+0200
# Frosinone Parma 2019-04-03T21:00:00+0200
# Genoa Inter 2019-04-03T21:00:00+0200
# Roma Fiorentina 2019-04-03T21:00:00+0200
# Spal Lazio 2019-04-03T21:00:00+0200
# Torino Sampdoria 2019-04-03T21:00:00+0200

# %%
for match in response.json()["data"]["matches"]:
    if datetime.strptime(match['date_match'][:10],'%Y-%m-%d').date() == current_date:
        print(match)
# Out:
# {'referees': {}, 'stadium': {}, 'identifier': 'ugq3pmqkngeyto3mrny18vcvy8mkxymu', 'match_slug': 'empoli-napoli', 'date_match': '2019-04-03T19:00:00+0200', 'home': {'team': 'Empoli', 'goals': -1, 'ball_possession': 0, 'goal_attempts': 0, 'shots_on_goal': 0, 'shots_off_goal': 0, 'blocked_shots': 0, 'free_kicks': 0, 'corner_kicks': 0, 'offsides': 0, 'throw_in': 0, 'goalkeeper_saves': 0, 'fouls': 0, 'red_cards': 0, 'yellow_cards': 0}, 'away': {'team': 'Napoli', 'goals': -1, 'ball_possession': 0, 'goal_attempts': 0, 'shots_on_goal': 0, 'shots_off_goal': 0, 'blocked_shots': 0, 'free_kicks': 0, 'corner_kicks': 0, 'offsides': 0, 'throw_in': 0, 'goalkeeper_saves': 0, 'fouls': 0, 'red_cards': 0, 'yellow_cards': 0}, 'match_result': '', 'played': 0}
# ...

# %%
remaining_requests
# Out:
# '8'

# %%
match
# Out:
# {'referees': {},
#  'stadium': {},
#  'identifier': '03xjv0i94pu0zzdv5wapqa3mgocd4vun',
#  'match_slug': 'wolverhampton-cardiff_city',
#  'date_match': '2019-03-02T16:00:00+0100',
#  'home': {'team': 'Wolverhampton',
#   'goals': 2,
#   'ball_possession': 0,
#   'goal_attempts': 0,
#   'shots_on_goal': 0,
#   'shots_off_goal': 0,
#   'blocked_shots': 0,
#   'free_kicks': 0,
#   'corner_kicks': 0,
#   'offsides': 0,
#   'throw_in': 0,
#   'goalkeeper_saves': 0,
#   'fouls': 0,
#   'red_cards': 0,
#   'yellow_cards': 0},
#  'away': {'team': 'Cardiff City',
#   'goals': 0,
#   'ball_possession': 0,
#   'goal_attempts': 0,
#   'shots_on_goal': 0,
#   'shots_off_goal': 0,
#   'blocked_shots': 0,
#   'free_kicks': 0,
#   'corner_kicks': 0,
#   'offsides': 0,
#   'throw_in': 0,
#   'goalkeeper_saves': 0,
#   'fouls': 0,
#   'red_cards': 0,
#   'yellow_cards': 0},
#  'match_result': '2-0',
#  'played': 1}

# %%
(datetime.today() - timedelta(4)).date()
# Out:
# datetime.date(2019, 3, 30)

# %%
endpoint = "https://apifootball.com/api/"
key = "fd24592b2afc1e750abaac83ab782c4026a02f0bda71cad131d93073c0555311"
from_date = "2019-04-09"
to_date = "2019-04-09"
params = {"APIkey" : key, "action" : "get_leagues", "to": to_date, "from": from_date}
response_countries = requests.get(endpoint, params = params)

# %%
endpoint = "https://apifootball.com/api/"
key = "fd24592b2afc1e750abaac83ab782c4026a02f0bda71cad131d93073c0555311"
current_date = (datetime.today() - timedelta(3)).date()
#from_date = datetime.strftime(current_date,'%Y-%m-%d')
#to_date = from_date
from_date = "2018-10-20"
to_date = "2018-10-20"
params = {"APIkey" : key, "action" : "get_events", "to": to_date, "from": from_date}
response = requests.get(endpoint, params = params)

# %%
leagues = ["62","117","109"]
#leagues = ["109"]
match_aggs = []
for match in response.json():
    match_agg = {}
    if match["league_id"] in leagues:
    #if league_id in used_leagues
    #if league_id is in list of used leagues (maybe only make request for these leagues)
        #send match to pub/sub
    #Below occurs on sub side
        print("{0} vs {1} {2}".format(match["match_hometeam_name"],match["match_awayteam_name"],match["match_id"]))
        match_agg["home_team"] = match["match_hometeam_name"]
        match_agg["away_team"] = match["match_awayteam_name"]
        match_agg["match_date"] = match["match_date"]
        match_agg["home_score"] = match["match_hometeam_score"]
        match_agg["away_score"] = match["match_awayteam_score"]
        match_agg["home_half_score"] = match["match_hometeam_halftime_score"]
        match_agg["away_half_score"] = match["match_awayteam_halftime_score"]
        for stat in match["statistics"]:
            if stat["type"] == "shots on target":
                match_agg["home_shots_on_target"] = stat["home"]
                match_agg["away_shots_on_target"] = stat["away"]
            elif stat["type"] == "shots off target":
                match_agg["home_shots_off_target"] = stat["home"]
                match_agg["away_shots_off_target"] = stat["away"]
            elif stat["type"] == "corners":
                match_agg["home_corners"] = stat["home"]
                match_agg["away_corners"] = stat["away"]
            elif stat["type"] == "offsides":
                match_agg["home_offsides"] = stat["home"]
                match_agg["away_offsides"] = stat["away"]
            elif stat["type"] == "fouls":
                match_agg["home_fouls"] = stat["home"]
                match_agg["away_fouls"] = stat["away"]
            elif stat["type"] == "yellow cards":
                match_agg["home_yellow_cards"] = stat["home"]
                match_agg["away_yellow_cards"] = stat["away"]
            elif stat["type"] == "goal kicks":
                match_agg["home_goal_kicks"] = stat["home"]
                match_agg["away_goal_kicks"] = stat["away"]

        match_id = match["match_id"]    
        params = {"APIkey" : key, "action" : "get_odds", "to": to_date, "from": from_date,"match_id": match_id}
        odds_response = requests.get(endpoint, params = params) 
        #{'error': 404, 'message': 'No odd found (please check your plan)!'}
        try:
            for odds in odds_response.json():
                if "bet365" in odds["odd_bookmakers"]:
                    match_agg["home_odds"] = odds["odd_1"]
                    match_agg["draw_odds"] = odds["odd_x"]
                    match_agg["away_odds"] = odds["odd_2"]
        except: 
            print(odds_response.json())
        match_aggs.append(match_agg)
# Out:
# Chelsea vs Manchester United 343762
# AFC Bournemouth vs Southampton 343763
# Cardiff City vs Fulham 343764
# Manchester City vs Burnley 343765
# Newcastle United vs Brighton &amp; Hove Albion 343766
# West Ham United vs Tottenham Hotspur 343767
# Wolverhampton Wanderers vs Watford 343768
# {'error': 404, 'message': 'No odd found (please check your plan)!'}
# Huddersfield Town vs Liverpool 343769
# Nuernberg vs Hoffenheim 345543
# {'error': 404, 'message': 'No odd found (please check your plan)!'}
# Bayer Leverkusen vs Hannover 96 345544
# Augsburg vs RasenBallsport Leipzig 345545
# VfB Stuttgart vs Borussia Dortmund 345546
# Wolfsburg vs Bayern Munich 345547
# Schalke 04 vs Werder Bremen 345548
# Real Madrid vs Levante 351082
# Valencia vs Leganes 351083
# Villarreal vs Atletico Madrid 351084
# Barcelona vs Sevilla 351085
# Valencia CF vs Leganes 359972
# {'error': 404, 'message': 'No odd found (please check your plan)!'}
# Barcelona vs Sevilla 359973
# ...

# %%
response.json()
# Out:
# [{'match_id': '341257',
#   'country_id': '175',
#   'country_name': 'Belgium',
#   'league_id': '144',
#   'league_name': 'Pro League',
#   'match_date': '2018-10-30',
#   'match_status': 'FT',
#   'match_time': '19:30',
#   'match_hometeam_name': 'Club Brugge',
#   'match_hometeam_score': '4',
#   'match_awayteam_name': 'Oostende',
#   'match_awayteam_score': '0',
#   'match_hometeam_halftime_score': '3',
#   'match_awayteam_halftime_score': '0',
#   'match_hometeam_extra_score': '',
#   'match_awayteam_extra_score': '',
#   'match_hometeam_penalty_score': '',
#   'match_awayteam_penalty_score': '',
#   'match_hometeam_system': '',
#   'match_awayteam_system': '',
#   'match_live': '0',
#   'goalscorer': [{'time': "16'",
#     'home_scorer': 'S.  Siebe Schrijvers',
#     'score': '1 - 0',
#     'away_scorer': ''},
#    {'time': "21'",
#     'home_scorer': 'H.  Hans Vanaken',
#     'score': '2 - 0',
#     'away_scorer': ''},
#    {'time': "45'",
#     'home_scorer': 'Wesley',
# ...

# %%
match_aggs[-4]
# Out:
# {'home_team': 'Valencia CF',
#  'away_team': 'Leganes',
#  'match_date': '2018-10-20',
#  'home_score': '1',
#  'away_score': '1',
#  'home_half_score': '0',
#  'away_half_score': '0',
#  'home_shots_on_target': '7',
#  'away_shots_on_target': '5',
#  'home_shots_off_target': '8',
#  'away_shots_off_target': '2',
#  'home_corners': '10',
#  'away_corners': '1',
#  'home_offsides': '2',
#  'away_offsides': '1',
#  'home_fouls': '10',
#  'away_fouls': '14',
#  'home_goal_kicks': '5',
#  'away_goal_kicks': '13'}

# %%
response_countries.json()
# Out:
# [{'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '996',
#   'league_name': 'Quarter Finals'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '1797',
#   'league_name': 'Qualification Preliminary Round'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '782',
#   'league_name': 'Group A'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '783',
#   'league_name': 'Group B'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '784',
#   'league_name': 'Group C'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '1812',
#   'league_name': 'Qualifying Round'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '785',
#   'league_name': 'Group D'},
#  {'country_id': '163',
#   'country_name': 'Champions League',
#   'league_id': '1840',
# ...

# %%
endpoint = "https://apifootball.com/api/"
key = "fd24592b2afc1e750abaac83ab782c4026a02f0bda71cad131d93073c0555311"
league_id = 109
params = {"APIkey" : key, "action" : "get_standings", "league_id": league_id}
league_response = requests.get(endpoint, params = params)

# %%
for league in league_response.json():
    print(league['team_name'])
# Out:
# Barcelona
# Real Madrid
# Atletico Madrid
# Valencia
# Getafe
# Girona
# Deportivo Alaves
# Real Sociedad
# Villarreal
# Sevilla
# Real Betis
# Athletic Bilbao
# Real Valladolid
# Levante
# Eibar
# RCD Espanyol
# Leganes
# Celta Vigo
# SD Huesca
# Rayo Vallecano

# %%
from_date = "2019-04-28"
to_date = "2019-04-28"
match_id = 407166
key = "fd24592b2afc1e750abaac83ab782c4026a02f0bda71cad131d93073c0555311"
params = {"APIkey" : key, "action" : "get_odds", "to": to_date, "from": from_date,"match_id": match_id}
odds_response = requests.get(endpoint, params = params)

# %%
for odds in odds_response.json():
    if odds["odd_bookmakers"] == "bet365.it":
        print(odds)
# Out:
# {'match_id': '407166', 'odd_bookmakers': 'bet365.it', 'odd_date': '2019-04-28 20:23:49', 'odd_1': '2.87', 'odd_x': '2.90', 'odd_2': '2.80', 'odd_1x': '', 'odd_12': '', 'odd_x2': '', 'ah-4.5_1': '', 'ah-4.5_2': '', 'ah-4_1': '', 'ah-4_2': '', 'ah-3.5_1': '', 'ah-3.5_2': '', 'ah-3_1': '', 'ah-3_2': '', 'ah-2.5_1': '', 'ah-2.5_2': '', 'ah-2_1': '', 'ah-2_2': '', 'ah-1.5_1': '6.40', 'ah-1.5_2': '1.11', 'ah-1_1': '5.25', 'ah-1_2': '1.16', 'ah0_1': '2.00', 'ah0_2': '1.93', 'ah+0.5_1': '1.45', 'ah+1_1': '1.16', 'ah+1_2': '5.25', 'ah+1.5_1': '1.11', 'ah+1.5_2': '6.40', 'ah+2_1': '', 'ah+2_2': '', 'ah+2.5_1': '', 'ah+2.5_2': '', 'ah+3_1': '', 'ah+3_2': '', 'ah+3.5_1': '', 'ah+3.5_2': '', 'ah+4_1': '', 'ah+4_2': '', 'ah+4.5_1': '', 'ah+4.5_2': '', 'o+0.5': '1.12', 'u+0.5': '6.00', 'o+1': '', 'u+1': '', 'o+1.5': '1.53', 'u+1.5': '2.50', 'o+2': '', 'u+2': '', 'o+2.5': '2.75', 'u+2.5': '1.44', 'o+3': '', 'u+3': '', 'o+3.5': '5.00', 'u+3.5': '1.16', 'o+4': '', 'u+4': '', 'o+4.5': '11.00', 'u+4.5':
# ...

# %%
if not "error" in odds_response.json():
    odds = odds_response.json()[0]
    print(odds.get("odd_1"))
    print(tofloat(odds.get("odd_x")))
    match_agg["away_odds"] = (odds.get("odd_2"))
# Out:
# 2.85
# 2.9

# %%
def tofloat(num):
    try:
        floatnum = float(num)
    except (ValueError, TypeError):
        floatnum = None
    return floatnum

# %%
odds_response.json()[0]
# Out:
# {'match_id': '407166',
#  'odd_bookmakers': 'Interwetten.es',
#  'odd_date': '2019-04-28 20:23:49',
#  'odd_1': '2.85',
#  'odd_x': '2.90',
#  'odd_2': '2.80',
#  'odd_1x': '',
#  'odd_12': '',
#  'odd_x2': '',
#  'ah-4.5_1': '',
#  'ah-4.5_2': '',
#  'ah-4_1': '',
#  'ah-4_2': '',
#  'ah-3.5_1': '',
#  'ah-3.5_2': '',
#  'ah-3_1': '',
#  'ah-3_2': '',
#  'ah-2.5_1': '',
#  'ah-2.5_2': '',
#  'ah-2_1': '',
#  'ah-2_2': '',
#  'ah-1.5_1': '',
#  'ah-1.5_2': '',
#  'ah-1_1': '',
#  'ah-1_2': '',
#  'ah0_1': '1.87',
#  'ah0_2': '1.83',
#  'ah+0.5_1': '',
#  'ah+1_1': '',
#  'ah+1_2': '',
#  'ah+1.5_1': '',
#  'ah+1.5_2': '',
#  'ah+2_1': '',
#  'ah+2_2': '',
#  'ah+2.5_1': '',
#  'ah+2.5_2': '',
#  'ah+3_1': '',
#  'ah+3_2': '',
#  'ah+3.5_1': '',
#  'ah+3.5_2': '',
#  'ah+4_1': '',
#  'ah+4_2': '',
#  'ah+4.5_1': '',
#  'ah+4.5_2': '',
#  'o+0.5': '',
#  'u+0.5': '',
#  'o+1': '',
#  'u+1': '',
#  'o+1.5': '',
#  'u+1.5': '',
#  'o+2': '',
#  'u+2': '',
#  'o+2.5': '',
#  'u+2.5': '',
# ...

# %%
data = {'match_date': '2019-04-21','time':None,'home_team': 'Leicester ', 'away_team': 'Arsenal', 'home_score': 3, 'away_score': 0, 'home_half_score': 0, 'away_half_score': 0, 'home_shots_on_target': 13, 'away_shots_on_target': 1, 'home_shots_off_target': 6, 'away_shots_off_target': 2, 'home_corners': 8, 'away_corners': 6, 'home_offsides': 2, 'away_offsides': 3, 'home_fouls': 13, 'away_fouls': 13, 'home_goal_kicks': 6, 'away_goal_kicks': 7, 'home_odds': 2.62, 'draw_odds': 3.75, 'away_odds': 2.62,'model_home':0,'model_away':0,'model_draw':0,'full_match_stats':True}

# %%
import pymongo #version = 3.8.0
import dns
client = pymongo.MongoClient("mongodb://nole1337:Npl454545!@matchdb-shard-00-00-volt6.gcp.mongodb.net:27017,matchdb-shard-00-01-volt6.gcp.mongodb.net:27017,matchdb-shard-00-02-volt6.gcp.mongodb.net:27017/test?ssl=true&replicaSet=matchdb-shard-0&authSource=admin&retryWrites=true")
collection = client.matchdb.matchmaster

# %%
query = {'match_date': '2019-04-28'}
orquery = {"$or":[ {"away_team":'Sevilla'}, {"home_team":'Sevilla'}]}
qdata = list(collection.find(query))
list(collection.find(query))
# Out:
# [{'_id': ObjectId('5cc9fe7e7d48f099b926fc90'),
#   'home_team': 'Burnley',
#   'away_team': 'Manchester City',
#   'match_date': '2019-04-28',
#   'time': '15:05',
#   'home_score': 0,
#   'away_score': 1,
#   'home_half_score': 0,
#   'away_half_score': 0,
#   'home_shots_on_target': 0,
#   'away_shots_on_target': 7,
#   'home_shots_off_target': 2,
#   'away_shots_off_target': 4,
#   'home_corners': 0,
#   'away_corners': 6,
#   'home_offsides': 2,
#   'away_offsides': 3,
#   'home_fouls': 5,
#   'away_fouls': 8,
#   'home_goal_kicks': 11,
#   'away_goal_kicks': 5,
#   'home_odds': 15.0,
#   'draw_odds': 7.5,
#   'away_odds': 1.17,
#   'model_home': 0.05755654722452164,
#   'model_draw': 0.13767948746681213,
#   'model_away': 0.8047639727592468,
#   'full_match_stats': True,
#   'away_yellow_cards': None,
#   'home_yellow_cards': None},
#  {'_id': ObjectId('5cc9fe7f7d48f099b926fc91'),
#   'home_team': '1. FC Nürnberg',
#   'away_team': 'FC Bayern München',
# ...

# %%
datalist = []
for x in data:
    datalist.append(x)
    print(x)
    #print(x["home_team"],x["away_team"])
# Out:
# {'_id': ObjectId('5cca2109e6385ffd393ba741'), 'home_team': 'Girona', 'away_team': 'Sevilla', 'match_date': '2019-04-28', 'time': '12:00', 'home_score': 1, 'away_score': 0, 'home_half_score': 0, 'away_half_score': 0, 'home_shots_on_target': 4, 'away_shots_on_target': 3, 'home_shots_off_target': 9, 'away_shots_off_target': 2, 'home_corners': 3, 'away_corners': 6, 'home_offsides': 5, 'away_offsides': 0, 'home_fouls': 12, 'away_fouls': 19, 'home_goal_kicks': 3, 'away_goal_kicks': 11, 'home_odds': 3.8, 'draw_odds': 3.7, 'away_odds': 1.95, 'model_home': None, 'model_draw': None, 'model_away': None, 'full_match_stats': True}
# ...

# %%
match_agg = match_aggs[0]
#mongodb+srv://nole1337:<password>@matchdb-volt6.gcp.mongodb.net/test?retryWrites=true
client = pymongo.MongoClient("mongodb://nole1337:Npl454545!@matchdb-shard-00-00-volt6.gcp.mongodb.net:27017,matchdb-shard-00-01-volt6.gcp.mongodb.net:27017,matchdb-shard-00-02-volt6.gcp.mongodb.net:27017/test?ssl=true&replicaSet=matchdb-shard-0&authSource=admin&retryWrites=true")
collection = client.matchdb.matchmaster
filter = {'match_date': match_agg["match_date"],'home_team':match_agg['home_team'],'away_team':match_agg['away_team']}
data = collection.find_one(filter)
if not data: 
    _id = collection.insert_one(match_agg)

# %%
#find_one_and_update for yesterday game updates

# %%
for x in datalist:
    print(x["home_team"],x["away_team"])
# Out:
# Girona Sevilla
# Real Valladolid Girona
# Celta Vigo Girona
# Girona Villarreal
# Girona RCD Espanyol
# Atletico Madrid Girona
# Girona Athletic Bilbao
# Leganes Girona
# Girona Valencia
# Rayo Vallecano Girona
# Girona Real Sociedad
# Real Madrid Girona
# Girona SD Huesca
# Eibar Girona
# Real Betis Girona
# Girona Getafe
# Sevilla Girona
# Athletic Bilbao Girona
# Girona Atletico Madrid
# RCD Espanyol Barcelona Girona
# Valencia CF Girona
# Girona Rayo Vallecano
# Real Sociedad Girona

# %%
match_agg = {'match_date': '2019-04-28','time':None,'home_team': 'Manchester United', 'away_team': 'Chelsea', 'home_score': 4, 'away_score': 1, 'home_half_score': 0, 'away_half_score': 0, 'home_shots_on_target': 13, 'away_shots_on_target': 1, 'home_shots_off_target': 6, 'away_shots_off_target': 2, 'home_corners': 8, 'away_corners': 6, 'home_offsides': 2, 'away_offsides': 3, 'home_fouls': 13, 'away_fouls': 13, 'home_goal_kicks': 6, 'away_goal_kicks': 7, 'home_odds': 2.62, 'draw_odds': 3.75, 'away_odds': 2.62,'full_match_stats':True}
update_data = {'$set': match_agg}


filter = {'home_team':"Manchester United",'away_team':"Chelsea",'match_date':"2019-04-28"}
#filter = {'home_shots_off_target':{ "$exists": False } }
#filter = {'away_score': None}

collection.find_one_and_update(filter,update_data)
#original = collection.find_one(filter)
#original.pop('_id')
(list(collection.find(filter)))
#collection.find_one(filter)
# Out:
# [{'_id': ObjectId('5ccb4ec7814c81216bdda6df'),
#   'home_team': 'Manchester United',
#   'away_team': 'Chelsea',
#   'match_date': '2019-04-28',
#   'time': None,
#   'home_score': 4,
#   'away_score': 1,
#   'home_half_score': 0,
#   'away_half_score': 0,
#   'home_shots_on_target': 13,
#   'away_shots_on_target': 1,
#   'home_shots_off_target': 6,
#   'away_shots_off_target': 2,
#   'home_corners': 8,
#   'away_corners': 6,
#   'home_offsides': 2,
#   'away_offsides': 3,
#   'home_fouls': 13,
#   'away_fouls': 13,
#   'home_goal_kicks': 6,
#   'away_goal_kicks': 7,
#   'home_odds': 2.62,
#   'draw_odds': 3.75,
#   'away_odds': 2.62,
#   'model_home': None,
#   'model_draw': None,
#   'model_away': None,
#   'full_match_stats': True}]

# %%
import numpy as np
from keras.models import load_model
from sklearn.externals import joblib
from sklearn.preprocessing import StandardScaler,LabelBinarizer

home_team = 'Chelsea'
away_team = 'Arsenal'
date = '2019-04-28'

def get_matches(team, date,collection):
    pred_filter = {"$or":[ {"away_team":team}, {"home_team":team} ]}
    matches = list(collection.find(pred_filter))
    curr_match = [match for match in matches if match["match_date"] == date]
    matches = [match for match in matches if match["match_date"] != date][:]
    for match in matches:
        match["match_date"] = datetime.strptime(match["match_date"],'%Y-%m-%d')
    matches = sorted(matches, key = lambda x: x["match_date"])
    matches = matches[-10:]
    return matches,curr_match[0]

def agg_values(matches,team):
    wins = 0
    losses = 0
    draws = 0
    goals = 0
    opp_goals = 0
    shots = 0
    shots_on = 0
    opp_shots = 0
    opp_shots_on = 0

    for match in matches:
        if match["home_team"] == team: 
            prefix = "home_"
            opp_prefix = "away_"
        if match["away_team"] == team: 
            prefix = "away_"
            opp_prefix = "home_"
        if match[prefix + "score"] > match[opp_prefix + "score"]:
            wins += 1
        elif match[prefix + "score"] < match[opp_prefix + "score"]:
            losses += 1
        elif match[prefix + "score"] == match[opp_prefix + "score"]:
            draws += 1
        else:
            print(match)
        goals += match[prefix + "score"]
        opp_goals += match[opp_prefix + "score"]
        shots += match[prefix + "shots_on_target"] + match[prefix + "shots_off_target"]
        shots_on += match[prefix + "shots_on_target"]
        opp_shots += match[opp_prefix + "shots_on_target"] + match[opp_prefix + "shots_off_target"]
        opp_shots_on += match[opp_prefix + "shots_on_target"]
    return np.array([wins,draws,losses,goals,opp_goals,shots,shots_on,opp_shots,opp_shots_on])

#convert dates into python datetime object
#remove date matching input param date 
#sort by date and slice top 10 most recent
client = pymongo.MongoClient("mongodb://nole1337:Npl454545!@matchdb-shard-00-00-volt6.gcp.mongodb.net:27017,matchdb-shard-00-01-volt6.gcp.mongodb.net:27017,matchdb-shard-00-02-volt6.gcp.mongodb.net:27017/test?ssl=true&replicaSet=matchdb-shard-0&authSource=admin&retryWrites=true")
collection = client.matchdb.matchmaster

home_matches, curr_match = get_matches(home_team,date,collection)
away_matches, _ = get_matches(away_team,date,collection)
home_arr = agg_values(home_matches,home_team)
away_arr = agg_values(away_matches,away_team)
odds_arr = np.array([curr_match["home_odds"],curr_match["draw_odds"],curr_match["away_odds"]])
temp_arr = np.append(home_arr,away_arr)
pred_input = np.array([(list(np.append(odds_arr,temp_arr)))])


model = load_model('soccer_odds_model.h5')
normalizer = joblib.load('normalizer.pkl') 

pred_input = normalizer.transform(pred_input)
prediction = model.predict(pred_input)[0]
# Out:
# Using TensorFlow backend.

# %%
arr = np.array([wins,losses,2])
arr2 = np.array([wins,losses,2])
np.array([(list(np.append(arr,arr2)))])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-319-9df52534d9fd> in <module>()
#       1 arr = np.array([wins,losses,2])
#       2 arr2 = np.array([wins,losses,2])
# ----> 3 np.array([(list(np.append(arr,arr2,arr)))])
#
# /anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4526         values = ravel(values)
#    4527         axis = arr.ndim-1
# -> 4528     return concatenate((arr, values), axis=axis)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
float(prediction[0][1])
# Out:
# 2.373931939914087e-09

# %%
arr
# Out:
# array([5, 3, 2])
